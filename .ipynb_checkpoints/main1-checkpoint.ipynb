# %%
import cv2
import pandas as pd
from ultralytics import YOLO
import cvzone
import numpy as np
import pytesseract
from datetime import datetime

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

model = YOLO('best.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        point = [x, y]
        print(point)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('mycarplate.mp4')


area = [(27, 417), (16, 456), (1015, 451), (992, 417)]

count = 0
list1 = []
processed_numbers = set()

# Open file for writing car plate data
with open("car_plate_data.txt", "a") as file:
    file.write("NumberPlate\tDate\tTime\n")  # Writing column headers

while True:    
    ret, frame = cap.read()
    count += 1
    if count % 3 != 0:
        continue
    if not ret:
       break
   
    frame = cv2.resize(frame, (1020, 500))
    results = model.predict(frame)
    a = results[0].boxes.data
    a = a.cpu()
    px = pd.DataFrame(a).astype("float")
   
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        
        d = int(row[5])
        cx = int(x1 + x2) // 2
        cy = int(y1 + y2) // 2
        result = cv2.pointPolygonTest(np.array(area, np.int32), ((cx, cy)), False)
        if result >= 0:
           crop = frame[y1:y2, x1:x2]
           gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
           gray = cv2.bilateralFilter(gray, 10, 20, 20)

           text = pytesseract.image_to_string(gray).strip()
           text = text.replace('(', '').replace(')', '').replace(',', '')
           if text not in processed_numbers:
              processed_numbers.add(text) 
              list1.append(text)
              current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
              with open("car_plate_data.txt", "a") as file:
                   file.write(f"{text}\t{current_datetime}\n")
                   cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 1)
                   cv2.imshow('crop', crop)

      
    cv2.polylines(frame, [np.array(area, np.int32)], True, (255, 0, 0), 2)
    cv2.imshow("RGB", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()    
cv2.destroyAllWindows()
# Out:
# 0: 320x640 (no detections), 96.9ms
# Speed: 6.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [282, 109]
#
# 0: 320x640 1 License_Plate, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [449, 404]
#
# 0: 320x640 1 License_Plate, 89.9ms
# Speed: 4.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [465, 432]
# [465, 434]
#
# 0: 320x640 1 License_Plate, 94.9ms
# Speed: 3.0ms preprocess, 94.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [477, 452]
#
# 0: 320x640 1 License_Plate, 89.9ms
# Speed: 3.0ms preprocess, 89.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# [478, 452]
#
# 0: 320x640 1 License_Plate, 93.9ms
# Speed: 4.0ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [489, 428]
#
# 0: 320x640 1 License_Plate, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [492, 415]
# [492, 414]
#
# 0: 320x640 1 License_Plate, 98.9ms
# Speed: 5.0ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [492, 407]
#
# 0: 320x640 1 License_Plate, 78.9ms
# Speed: 3.0ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 69.0ms
# Speed: 4.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 68.0ms
# Speed: 5.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 68.0ms
# Speed: 4.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 73.9ms
# Speed: 3.0ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 73.0ms
# Speed: 4.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# [492, 407]
#
# 0: 320x640 1 License_Plate, 67.4ms
# Speed: 2.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [492, 407]
#
# 0: 320x640 1 License_Plate, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 61.0ms
# Speed: 4.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 111.9ms
# Speed: 70.0ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [492, 407]
#
# 0: 320x640 1 License_Plate, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [492, 407]
#
# 0: 320x640 1 License_Plate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 63.0ms
# Speed: 5.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 70.9ms
# Speed: 2.0ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 68.0ms
# Speed: 4.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 64.0ms
# Speed: 4.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 License_Plate, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.0ms
# Speed: 4.1ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 69.0ms
# Speed: 4.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 63.0ms
# Speed: 4.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.4ms
# Speed: 3.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 60.0ms
# Speed: 4.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.0ms
# Speed: 4.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 70.5ms
# Speed: 2.0ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 61.0ms
# Speed: 4.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.2ms
# Speed: 4.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 61.3ms
# Speed: 2.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.9ms
# Speed: 3.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 84.9ms
# Speed: 3.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
